# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df = df[["text","score","kelas"]]
# Out:
#                                                    text  score    kelas
# 0                         serius vaksin corona ditemuin -1.000  negatif
# 1           kesehatan kau corona sembuh mengapai vaksin  1.000  positif
# 2     wapres uea sheikh mohammed terima uji coba vak...  0.000   netral
# 3       pengawalan pencabutan izin darurat vaksin covid  0.000   netral
# 4      pemerintahannya dicap tergesagesa jokowi peng...  0.000   netral
# ...                                                 ...    ...      ...
# 4937  pandemi covid dian pelangi dandan sebulan anak...  0.000   netral
# 4938   diborong importir kandidat vaksin direkomenda...  1.000  positif
# 4939  pemerintah pasokan vaksin covid who cegah clus...  0.000   netral
# 4940  pemerintah awasi ketat pembuatan vaksin covid ... -2.000  negatif
# 4941                                                NaN  0.055      NaN
#
# [4942 rows x 3 columns]

# %%
for i in range(len(df)):
    print(f" {i} -> {df.loc[i,'text']}")
HateSpeech = [7,]
cobaCek = [25,403,]
# Out:
#  0 -> serius vaksin corona ditemuin
#  1 -> kesehatan kau corona sembuh mengapai vaksin
#  2 -> wapres uea sheikh mohammed terima uji coba vaksin virus corona
#  3 ->  pengawalan pencabutan izin darurat vaksin covid
#  4 ->  pemerintahannya dicap tergesagesa jokowi pengadaan vaksin corona hatihati
#  5 ->  tidakaman uji klinik vaksin covid dihentikan
#  6 -> beda vaksin vaksinasi imunisasi
#  7 -> vaksin corona gratis bayar jokowi harganya terjangkau
#  8 -> gue gendong kucing emak gue kak coba cek infojakarta vaksin gratis gue kaget hah vaksin corona gratis emak gue vaksin corona vaksinnya sih ebong gue menatap ebong hadeh
#  9 -> tujuan vaksinasi bagus vaksinasi terbentuk antibody tubuh virus case vaksin covid hasil test nya masyarakat tau hasil resminya nada dipaksa
#  10 ->  tercepat dunia ya
#  11 ->  roadmap presiden status kondisi vaksin diperoleh memaksakan resiko
#  12 ->  vaksinasi covid november tercepat didunia europe jepang us kuartal hasil test tuntas
# ...

# %%
HateSpeech = [1484,]

# %% [markdown]
# ##  Mostly Data dari berita ini mah , sedikit opini dari orang,so HateSpeechnya or offensivenya dikit
