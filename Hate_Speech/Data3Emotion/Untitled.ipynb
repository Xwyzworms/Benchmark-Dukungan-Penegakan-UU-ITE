# %%
import pandas as pd
import numpy as np

import os

# %%
df = pd.read_csv("Emotion.csv")
df.head()
# Out:
#    label                                              tweet
# 0  anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  happy  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %%
df["label"].unique()

anger = df[df["label"] == "anger"].loc[:,"tweet"]
fear  = df[df["label"] == "fear"].loc[:,"tweet"]
sad = df[df["label"] == "sadness"].loc[:,"tweet"]

print(len(anger),
     len(fear),
     len(sad))
# Out:
# 1101 649 997

# %%
for i in range(len(anger)):
    print(f"{i} -> {anger.iloc[i]}")
HateSpeech = [35,46]
offensive = [61,70,96,119,]
# Out:
# 0 -> Soal jln Jatibaru,polisi tdk bs GERTAK gubernur .Emangny polisi tdk ikut pmbhasan? Jgn berpolitik. Pengaturan wilayah,hak gubernur. Persoalan Tn Abang soal turun temurun.Pelik.Perlu kesabaran. [USERNAME] [USERNAME] [URL]
# 1 -> Sesama cewe lho (kayaknya), harusnya bisa lebih rasain lah yang harus sibuk jaga diri, rasain sakitnya haid, dan paniknya pulang malem sendirian. Gimana orang asing? Wajarlah banyak korban yang takut curhat, bukan dibela malah dihujat.
# 2 -> Jln Jatibaru,bagian dari wilayah Tn Abang.Pengaturan wilayah tgg jwb dan wwnang gub.Tng Abng soal rumit,sejak gub2 , trdahulu.Skrg sedng dibenahi,agr bermnfaat semua pihak.Mohon yg punya otak,berpikirlah dgn wajar,kecuali otaknya butek.Ya kamu. [URL]
# 3 -> Dari sekian banyak thread yang aku baca, thread ini paling aneh sih dalam penulisan. Sumpah aneh bgt, mau ngatain "lebay" aja segala bikin thread hadeh. Aku juga ga jago nulis, tapi tulisan aku ga seberantakan thread mbaknya.
# ...
